# %%
import pandas as pd

# %%
df = pd.read_csv("loan.csv")

# %%
df["Gender"].fillna(df["Gender"].mode()[0],inplace=True)

# %%
df.head(10)
# Out:
#   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0  LP1000    Male     Yes          2      Graduate            No
# 1  LP1001    Male     Yes          0      Graduate           NaN
# 2  LP1002  Female     Yes          0      Graduate            No
# 3  LP1003  Female     Yes         3+      Graduate            No
# 4  LP1004    Male      No          2      Graduate            No
# 5  LP1005    Male     Yes          0  Not Graduate            No
# 6  LP1006    Male     Yes          0      Graduate            No
# 7  LP1007  Female      No          2      Graduate           Yes
# 8  LP1008  Female     Yes          0  Not Graduate           NaN
# 9  LP1009  Female     Yes          0      Graduate           Yes
#
#    ApplicantIncome  LoanAmount
# 0            16337       370.0
# 1            24986       280.0
# 2             8812       190.0
# 3             6820       340.0
# 4            14716         NaN
# 5            24016       460.0
# ...

# %%
import sklearn.preprocessing as LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
new = df["Gender"] = le.fit_transform(df["Gender"])

# %%
df
# Out:
#    Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP1000       1     Yes          2      Graduate            No
# 1   LP1001       1     Yes          0      Graduate           NaN
# 2   LP1002       0     Yes          0      Graduate            No
# 3   LP1003       0     Yes         3+      Graduate            No
# 4   LP1004       1      No          2      Graduate            No
# ..     ...     ...     ...        ...           ...           ...
# 95  LP1095       0     Yes          2  Not Graduate            No
# 96  LP1096       0      No         3+  Not Graduate            No
# 97  LP1097       1      No          0      Graduate           Yes
# 98  LP1098       1      No          2  Not Graduate           NaN
# 99  LP1099       1      No          0  Not Graduate           NaN
#
#     ApplicantIncome  LoanAmount
# 0             16337       370.0
# 1             24986       280.0
# 2              8812       190.0
# 3              6820       340.0
# ...

# %%
df["Gender"].unique()
# Out:
# array([1, 0])
