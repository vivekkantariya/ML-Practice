# %%
import pandas as pd
import seaborn as sns

# %%
data = {"Name":["Vivek","Trushang","Vivek","Raj"],"Sub":["English","Maths","English","Science",],"Div":["A","B","A","C",]}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#        Name      Sub Div
# 0     Vivek  English   A
# 1  Trushang    Maths   B
# 2     Vivek  English   A
# 3       Raj  Science   C

# %%
df["Duplicates"] = df.duplicated()          # finds the duplicate

# %%
df
# Out:
#        Name      Sub Div  Duplicates
# 0     Vivek  English   A       False
# 1  Trushang    Maths   B       False
# 2     Vivek  English   A        True
# 3       Raj  Science   C       False

# %%
da = pd.read_csv("loan.csv")

# %%
da["Duplicates"] = da.duplicated()          # finds the duplicate

# %%
da
# Out:
#    Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP1000    Male     Yes          2      Graduate            No
# 1   LP1001     NaN     Yes          0      Graduate           NaN
# 2   LP1002  Female     Yes          0      Graduate            No
# 3   LP1003  Female     Yes         3+      Graduate            No
# 4   LP1004    Male      No          2      Graduate            No
# ..     ...     ...     ...        ...           ...           ...
# 95  LP1095  Female     Yes          2  Not Graduate            No
# 96  LP1096  Female      No         3+  Not Graduate            No
# 97  LP1097    Male      No          0      Graduate           Yes
# 98  LP1098    Male      No          2  Not Graduate           NaN
# 99  LP1099    Male      No          0  Not Graduate           NaN
#
#     ApplicantIncome  LoanAmount  Duplicates
# 0             16337       370.0       False
# 1             24986       280.0       False
# ...

# %%
da["Duplicates"] = da.duplicated()         # finds the duplicate

# %%
da
# Out:
#    Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP1000    Male     Yes          2      Graduate            No
# 1   LP1001     NaN     Yes          0      Graduate           NaN
# 2   LP1002  Female     Yes          0      Graduate            No
# 3   LP1003  Female     Yes         3+      Graduate            No
# 4   LP1004    Male      No          2      Graduate            No
# ..     ...     ...     ...        ...           ...           ...
# 95  LP1095  Female     Yes          2  Not Graduate            No
# 96  LP1096  Female      No         3+  Not Graduate            No
# 97  LP1097    Male      No          0      Graduate           Yes
# 98  LP1098    Male      No          2  Not Graduate           NaN
# 99  LP1099    Male      No          0  Not Graduate           NaN
#
#     ApplicantIncome  LoanAmount  Duplicates
# 0             16337       370.0       False
# 1             24986       280.0       False
# ...

# %%
df.shape
# Out:
# (100, 9)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (100, 9)
